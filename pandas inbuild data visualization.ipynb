# %%
#pandas inbuild data visualization
import pandas as pd
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df1 = sns.load_dataset('tips')

# %%
df2 = pd.read_csv('ece.csv')

# %%
x1 = np.random.rand(100,5)

# %%
x2 = np.random.rand(10,5)

# %%
df3 = pd.DataFrame(x1, columns =['a','b','c','d','e'])

# %%
df4 = pd.DataFrame(x2, columns =['a','b','c','d','e'])

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
df3.plot.scatter(x = 'a',y ='b')

# %%
df4.plot.scatter(x = 'a',y ='b')

# %%
df1.plot.scatter(x = 'total_bill',y ='tip')

# %%
#lineplots
df3.plot.line()

# %%
df3['c'].plot.line()

# %%
df4['a'].plot.line()

# %%
df4.plot.line()

# %%
df4.plot.kde()

# %%
df3.plot.kde()

# %%
df4.plot.density()

# %%
#distribution plots

df4.plot.hist()

# %%
df4.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025A20825630>,
# ...
#       dtype=object)

# %%
df4['b'].hist()

# %%
df4[['b','c']].plot.hist()

# %%
df4.plot.hist()
df4.plot.bar()

# %%
df3.plot.bar()

# %%
df3['a'].plot.bar()

# %%
df4.plot.area()

# %%
df4.plot.area(alpha = 0.5)

# %%
df1.plot(kind='hist')

# %%
df4.plot.box()

# %%
df4['a'].plot.box()

# %%
df1.plot.hexbin(x = 'total_bill', y = 'tip', gridsize= 10)

# %%
df4.plot.hexbin(x = 'a', y = 'b', gridsize= 10)

# %%
df3.plot.hexbin(x = 'a', y = 'b', gridsize= 10,cmap = 'cool')

# %%
#https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
